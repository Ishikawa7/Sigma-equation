# %%
# load numpy file named tensore_equazione_sigma_book.npy
import numpy as np
tensore_equazione_sigma = np.load('tensore_equazione_sigma_book.npy')
tensore_equazione_sigma
# Out:
# array([[[[[0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02],
#           [0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02],
#           [0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02],
#           [0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02],
#           [0.00000000e+00, 1.00000000e+00, 4.00000000e+00, ...,
#            6.40000000e+01, 8.10000000e+01, 1.00000000e+02]],
#
#          [[8.24930561e-01, 1.82493056e+00, 4.82493056e+00, ...,
#            6.48249306e+01, 8.18249306e+01, 1.00824931e+02],
#           [8.34930561e-01, 1.83493056e+00, 4.83493056e+00, ...,
# ...
